# %%
# PyTests - write test cases for your python code

# goal is to increase code coverage - how much percentage of your code has unit tests defined ?


# MagicMock -> Magic Mock will allow you to mock external services in your code so that you can focus on writing tests for your 
# logic in your python code

# %%
# Assert in python

a = 10
b = 10

assert a == b

# %%
def test_somefunction():
    expected_value = 10
    actual_value = somefunction()
    assert expected_value == actual_value
